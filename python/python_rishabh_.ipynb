# %%
#string in python,variable names are case-sensitive
string = "hey"
String = "hi"
print(String)


print("Hello World!")
print("I like typing this.")
print("_-"*40)

string0 ='Welcome to first class of python'
string1 ="Welcome to first class of python"
string2 = """Welcome to first
class
of
python"""

print(string0)
print("_-"*40)
print(string1)
print("_-"*40)
print(string2
      
print("this is a line1")
print("this is a line2")
print("this is a line1 " , end ="") #single line
print("this is a line2")
print("this is a line2" * 23)#it will print this 23 times
# a string name should always start with a alphabet or an underscore, u cant start ur string with a number. in between you can have
#the interpreter will understand it differently
# Out:
# hi

# %%
name ="asdfghj"
print(name[0])        # Char at index 0
print(name[-1])
print(name[0:4])      # Substring from index 0 to 3
print(name[2:])       # Substring from index 2 to end of string
print(name[:3])       # Substring from start to index 2 
print(name[:])        # Substring from start to end
print(name[2:5:2])    # Characters from index 2 to 4 in steps of 2
print(name[::-1])     # Complete string taking a step of -1
print(len(name))

print(name.find("df"))      # First index where "dy" is found
print(name.find("ty"))      # Returns -1 if not found
print(name.find("df",2,5))  # finds string from index 2 to 4
print(name.find("df",4,6))

print(name.index('df'))
#print(name.index('ty'))     # error
# Out:
# a
# j
# asdf
# dfghj
# asd
# asdfghj
# dg
# jhgfdsa
# 7
# 2
# -1
# 2
# -1
# 2

# %%
print(name.capitalize())
print(name.lower())
print(name.upper())
print(name)

print(name.endswith('j'))
print(name.endswith('a'))

print(name.count('a',0,7)) # Start and end index mentioned
print(name.count('a'))
print(name.count('b'))

# %%
# Integer - int
a = 10
print(a, type(a))

# String - str
b = "Computer Coding Club"
print(b, type(b))

# Float - float
num = 3.244
print(num, type(num))

# Boolean - bool
flag = False
print(flag, type(flag))
# Out:
# 10 <class 'int'>
# Computer Coding Club <class 'str'>
# 3.244 <class 'float'>
# False <class 'bool'>

# %%
int1 =5 
int2 = 6
print("the int1 + int2 is  : " , int1+int2) 
print("the int1 - int2 is  : " , int1-int2) 
print("the int1 * int2 is  : " ,(int1*int2) ) 
print("the int1 / int2 is  : " , (int1/int2 )) 
print("the int1 ** int2 is  : " , int1**int2) 
print("the int1 % int2 is  : " , int1%int2)

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()

# %%
x = "awesome"

def myfunc():
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)

# %%
def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)x = "awesome"

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)

# %%
x = "awesome"

def myfunc():
  global x
  x = "fantastic"

myfunc()

print("Python is " + x)

# %%
integer = 5
floatingpoint = 5.6
#variables numnbers integers floating lists dict (map)

# %%
#multi line string
multilinestring = ''' thias 
ia  
a fnnfjlkdnf
'''
print(multilinestring)
# Out:
#  thias
# ia
# a fnnfjlkdnf

# %%
#lists the indexing start with 0,
players = ["messi", "ronaldo", "other players"]#messi is 0th index, ronanldo is 1st index ....
data = ["abc", 12 , True , 1.23 ] 
#priniting
print(players)
print(data)

#Accessing single item from list (indexing)

# Positive Indexing
print(players[1])
print(data[3])

# Negative Indexing
print(players[-1])
print(players[-2])



#MUTABLE
players[2] = "neymar"
print(players) 
integer = [1,2,3,4]
print(integer[1]+integer[2])
print(integer[1]-integer[2])
print(integer[1]*integer[2])
print(integer[1]**integer[2])

# Adding an element to existing list
integer.append(5)#adding a element
print(integer)
integer.insert(3,6)#adding a element at a specific index
print(integer)

#removing a elememt from our list
integer.remove(5)#removing an element
print(integer)

#adding multiple element
print(integer + [ 7,8,9])
print(integer)

#some inbuilt functions
print(len(integer)) #lenght of string
print(max(integer)) #max element of the string or integer
print(min(integer))

# %%
 #tuples they are lists only but the difference is that you cant change the values in tuples
#append insert remove att are not present
 l = (1,2,3)
print(l)
 list1 = list(l)
print(list1)
list1.append(4)
list1.insert(3,5)
print(list1)
# Out:
# (1, 2, 3)
# [1, 2, 3]
# [1, 2, 3, 5, 4]

# %%
#dictonary
dict1 = {"cricket bat":100,
        "cricket ball" : 10,
        "cricket pads": 50,
        "cricket gloves":40}
print(dict1.keys())#dict1.keys will give you name of all the objects
print(dict1.values())#dict1.values will give you the values of those objects
print(dict1['cricket bat'])#this way you can call values for any object
# Out:
# dict_keys(['cricket bat', 'cricket ball', 'cricket pads', 'cricket gloves'])
# dict_values([100, 10, 50, 40])
# 100

# %%
#if else conditons and logical operators

# %%
# Tuple of Strings
colors = ("Red", "Blue", "Green")
print(colors)
# Heterogenous tuple
hetero_tuple = ("Possible?", 2.3, 4, True, [1, "Again"], (2, 5.67, "CC Classes"))
print(hetero_tuple)

print("Positive Indexing: ", hetero_tuple[2])
print("Negative Indexing: ", hetero_tuple[-1])

# %%
# Tuple is Immuatable - trying to reassign
colors[0] = "Purple" # This will give error

# %%
myset = {3,2,1}
fruits = {"apple", "banana", "cherry"}
print(myset)
print(fruits)
#myset.append(3)


myset.add(4)
myset.add(8)
myset.add(4)
print("After adding: ", myset)

myset.pop()
print("After popping: ", myset)

myset.remove(3)
print("After removing 3: ", myset)

myset.discard(2)
print("After discarding 2: ", myset)

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict)

# Accessing value using key
print("Brand: ", thisdict["brand"])
print("Model: ", thisdict.get("model"))

# Adding a key value pair to dictionary
thisdict["electric"] = False
thisdict.update({"color": "green"})
print("After updating: ", thisdict)

# Printing all keys of dictionary
print("Keys: ", thisdict.keys())

# Deleting a key-value pair
thisdict.pop("color")
print("After popping: ", thisdict)

# %%
# If-Else conditions Syntax

# if condition :
#      statements
# elif condition:
#      statements
# else:
#      statements

age = 13
if age < 18:
    print("You cannot vote!")

# Use of "is" operator
#name = "Foo"
name = "Bar"
if name is "Foo":
    print("Hey there Foo")
elif name == "Bar":
    print("What's up Bar!")
else:
    print("Please sign up for the site!")
    
# Use of "in" operator
students = ["Alice", "Bob", "Foo", "Bar"]
stu_name = "Bob"
if stu_name in students:
    print("Hello", stu_name, "You are enrolled")
else:
    print("You are not enrolled!")
    
# Use of "and" operator
user_name = "abc"
password = "123"
if user_name is "abc" and password = "123":
    print("Access granted")
else:
    print("Access denied")

# Use of "or" operator
age = 30
if age <10 or age >25:
    print ("Not golden years")
else:
    print("Golden years")

# %%
# For loop
# from 0 to 9
for x in range(10):
    print(x, end=",")

print("")

# from 5 to 11
for x in range(5, 12):
    print(x, end=",")

print("")

# from 10 to 40 (not included), increment value 5
for x in range(10, 40, 5):
    print(x, end=",")

print("")

# While loop
i = 5
while i < 10:
    print(i, end=",")
    i += 1


i = 1
while i < 6:
  print(i)
  if i == 3:
    break
  i += 1

i = 0
while i < 6:
  i += 1
  if i == 3:
    continue
  print(i ) 

i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")    

print("")

# Adding elements to an empty list
mylist = []
for x in range(10, 20, 3):
    mylist.append(x)

print("My List: ", mylist)

# %%
# Iterating over list in Python
colors = ["Red", "Green", "Blue", "White", "Black"]
for color in colors:
    print(color)

print("")
# Iterating over a dictionary
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

for key in thisdict.keys():
    print("Key:", key, "| Value:", thisdict[key])

print("")

for key, value in thisdict.items():
    print("Key:", key, "| Value:", value)

# %%
# Funciton without parameters

# Defining function
def func():
    print('Hello')

# Calling function    
func()
# Function with parameters
def purchase(egg_count):
  print(egg_count)

purchase(10)

# Funcgtion with default parameters
def purchase(egg_count=10):
  print(egg_count)

purchase()
purchase(20)

def greet(name, msg = "Good morning!"):
    print(name,msg)
    
greet("Alice")
greet("Foo Bar")
greet("Bob", "Good Afternoon!")

# %%
def names(name1, name2):
  print(name1, name2)

names(1,"mohit")
# Out:
# 1 mohit

# %%
#input
a = input("Enter you name:")
print("Hello",a)

a = input("Enter a number.")
print(a, type(a))

a = int (input("Enter a number"))
b = int (input("Enter another number"))
print("Sum of both the numbers is: ", a+b)

# %%
double = lambda x: x * 2

# Output: 10
print(double(5))

#list'
list1= [1,2,3,4,5]
print(list (map(lambda x: x*2 , list1)))#map can be used for mapping the entrire data structure

def fun(n):
  return lambda x :x*n

fun1 = fun(3)
fun2 = fun(4)

print(fun1(9))
print(fun2(9))
# Out:
# 10
# [2, 4, 6, 8, 10]
# 27
# 36
